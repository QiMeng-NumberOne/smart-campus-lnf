# %%
from ultralytics import YOLO

model = YOLO('runs/detect/train/weights/best.pt')

# 直接把 source 写成文件夹的名字！
results = model.predict(
    source='test_images/', # 这里直接填文件夹路径
    conf=0.5,
    save=True
)

print("🎉 整个文件夹的图片都识别完了！")
# Out:
# image 1/9 d:\MyProject\smart-campus-lnf\yolo_model\test_images\bag_00pp-louis-vuitton-palm-springs-small-model-backpack-in-brown-monogram-canvas-and-black-leather_jpg.rf.sInD9ecYE1V3dAjgKYhH.jpg: 640x640 1 bag, 16.6ms
# image 2/9 d:\MyProject\smart-campus-lnf\yolo_model\test_images\book_ee1f6300551f4a1a_jpg.rf.zbeMLYv2angSAQCcMuWz.jpg: 640x640 4 books, 16.2ms
# image 3/9 d:\MyProject\smart-campus-lnf\yolo_model\test_images\flashdrive_download (9)_jpg.rf.yOfeDXhMb8STjRvFYiwU.jpg: 640x640 1 flashdrive, 10.9ms
# image 4/9 d:\MyProject\smart-campus-lnf\yolo_model\test_images\headphone1.jpg: 512x640 (no detections), 16.2ms
# image 5/9 d:\MyProject\smart-campus-lnf\yolo_model\test_images\headphone_headphone20_jpg.rf.kFkaDIy3DYttCWaEIqSg.jpg: 640x640 1 headphone, 9.6ms
# image 6/9 d:\MyProject\smart-campus-lnf\yolo_model\test_images\images (44)_jpg.rf.ufJuygaI7ZfuKSo4mrb7.jpg: 544x640 1 headphone, 10.5ms
# ...
